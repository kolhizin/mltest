# %%
import numpy as np
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
import datetime, time

import modutils

data_dir = '../DataSets/Churn/'

# %%
fname = data_dir + 'user_logs.csv'
batch_size = 1000000 #1mln
num_steps = 600 #more than needed
res = None

with open(fname, 'r') as f:
    f.readline()
    for step in range(num_steps):
        t0 = time.perf_counter()
        lines = [f.readline().replace('\n','').split(',') for i in range(batch_size)]
        if lines is None or len(lines) == 0:
            print('\nStopped at {0} steps'.format(num_steps))
            break
        flines = [x for x in lines if int(x[1])>20170200]
        if len(flines)==0:
            continue
        tmp = pd.DataFrame(data=flines,
                           columns=['msno', 'dt', 'num_25', 'num_50', 'num_75', 'num_985', 'num_100', 'num_unq', 'totsec'])
        t1 = time.perf_counter()
        if res is None:
            res = tmp
        else:
            res = pd.concat([res,tmp])
        print('Step {0}: Read {1} entries (total: {2}) in {3:.2f} seconds'.format(step, len(tmp), len(res), t1-t0), end='\r')
# Out:
# Step 121: Read 41316 entries (total: 5002988) in 4.41 seconds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-6a54ccdfe0c8> in <module>()
#       8     for step in range(num_steps):
#       9         t0 = time.perf_counter()
# ---> 10         lines = [f.readline().replace('\n','').split(',') for i in range(batch_size)]
#      11         if lines is None or len(lines) == 0:
#      12             print('\nStopped at {0} steps'.format(num_steps))
#
# <ipython-input-51-6a54ccdfe0c8> in <listcomp>(.0)
#       8     for step in range(num_steps):
#       9         t0 = time.perf_counter()
# ---> 10         lines = [f.readline().replace('\n','').split(',') for i in range(batch_size)]
#      11         if lines is None or len(lines) == 0:
#      12             print('\nStopped at {0} steps'.format(num_steps))
#
# C:\Anaconda3\lib\encodings\cp1251.py in decode(self, input, final)
#      20
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
# ---> 22     def decode(self, input, final=False):
#      23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#
# KeyboardInterrupt:

# %%
ress = res.sort_values(by=['msno','dt'])

# %%
ress.to_csv(data_dir + 'user_log1702_part.csv')

# %%
fname_log = data_dir + 'user_log1702_part.csv'
fname_trgt = data_dir + 'train.csv'

src_log = pd.read_csv(fname_log)
src_trgt = pd.read_csv(fname_trgt)

# %%
src = pd.merge(left=src_log, right=src_trgt, how='left', on='msno')

# %%
src['num_tot'] = src.num_25 + src.num_50 + src.num_75 + src.num_985 + src.num_100
src['pct_low'] = src.num_25 / src.num_tot
src['pct_high'] = (src.num_50 + src.num_75 + src.num_985) / src.num_tot
src['pct_full'] = src.num_100 / src.num_tot
src['pct_unq'] = src.num_unq / src.num_tot
src['avg_sec'] = src.totsec / src.num_tot
src['avg_sec100'] = src.totsec / np.maximum(1, src.num_100)

# %%
src['lgt_low'] = np.log(np.maximum(0.001, src.pct_low) / (1 - np.minimum(0.999, src.pct_low)))
src['f0_low'] = 1.0*(src.pct_low <= 0.001)
src['f1_low'] = 1.0*(src.pct_low >= 0.999)

src['lgt_high'] = np.log(np.maximum(0.001, src.pct_high) / (1 - np.minimum(0.999, src.pct_high)))
src['f0_high'] = 1.0*(src.pct_high <= 0.001)
src['f1_high'] = 1.0*(src.pct_high >= 0.999)

src['lgt_full'] = np.log(np.maximum(0.001, src.pct_full) / (1 - np.minimum(0.999, src.pct_full)))
src['f0_full'] = 1.0*(src.pct_full <= 0.001)
src['f1_full'] = 1.0*(src.pct_full >= 0.999)

src['lgt_unq'] = np.log(np.maximum(0.001, src.pct_unq) / (1 - np.minimum(0.999, src.pct_unq)))
src['f0_unq'] = 1.0*(src.pct_unq <= 0.001)
src['f1_unq'] = 1.0*(src.pct_unq >= 0.999)

src['ln_num_tot'] = np.log(src.num_tot)
src['ln_num_100'] = np.log(1 + src.num_100)

src['ln_tot_sec'] = np.log(src.totsec)
src['mx_avg_sec'] = np.minimum(360, src.avg_sec)

pct_modifiers = ['f0', 'f1', 'lgt'] 
pct_sources = ['low', 'high', 'full', 'unq']
other_features = ['ln_num_tot', 'ln_tot_sec', 'mx_avg_sec']

features = other_features + [x+'_'+y for x in pct_modifiers for y in pct_sources]
target = 'is_churn'

# %%
#src01 = src[(src.dt==20170201)&(~np.isnan(src.is_churn))]
src01 = src[(~np.isnan(src.is_churn))]

# %%
devX = np.array(src01[features])
devY = np.array(src01[target])
(trainX, trainY), (testX, testY) = modutils.splitSample((devX, devY), pcts=[0.7, 0.3])

# %%
import sklearn
import sklearn.linear_model, sklearn.ensemble, sklearn.metrics

def eval_model(m, tX, tY):
    tP = m_logreg01.predict_proba(tX)[:,1]
    tL = np.log(tP / (1-tP))
    return sklearn.metrics.roc_auc_score(tY, tL)*2-1

# %%
t0 = time.perf_counter()
m_logreg01 = sklearn.linear_model.LogisticRegression(penalty='l1').fit(trainX, trainY)
t1 = time.perf_counter()
g = eval_model(m_logreg01, trainX, trainY)
print('Trained in {0:.2f} seconds, gini = {1:.3f}'.format(t1-t0,g))
# Out:
# Trained in 82.47 seconds, gini = 0.047

# %%
t0 = time.perf_counter()
m_gboost01 = sklearn.ensemble.GradientBoostingClassifier().fit(trainX, trainY)
t1 = time.perf_counter()
g = eval_model(m_gboost01, trainX, trainY)
print('Trained in {0:.2f} seconds, gini = {1:.3f}'.format(t1-t0,g))
# Out:
# Trained in 11.15 seconds, gini = 0.054

# %%
t0 = time.perf_counter()
m_gboost02 = sklearn.ensemble.GradientBoostingClassifier(min_samples_leaf=100, min_samples_split=100, max_depth=5, n_estimators=200).fit(trainX, trainY)
t1 = time.perf_counter()
g = eval_model(m_gboost02, trainX, trainY)
print('Trained in {0:.2f} seconds, gini = {1:.3f}'.format(t1-t0,g))
# Out:
# Trained in 36.81 seconds, gini = 0.054

# %%
src_p = m_logreg01.predict_proba(np.array(src[features]))[:,1]

# %%
src['f_lgt'] = np.log(src_p / (1-src_p))

# %%
plt.hist(src[src.f_lgt <-2].f_lgt, bins=40)
plt.show()

# %%
tmp = src.copy()

# %%
tmp['g'] = np.floor(tmp.f_lgt*10)/10
tmp.groupby('g')['is_churn'].mean()

# %%
srcg = src.groupby('msno').agg({'dt':['min','max','count'], 'num_tot':['min','max','mean'], 'f_lgt':['min','max','mean'],'is_churn':'mean'})

# %%
srcg.columns = ['_'.join(x) for x in srcg.columns.ravel()]
srcg.rename(columns={'is_churn_mean':'is_churn'})
# Out:
#                                                 dt_min    dt_max  dt_count  \
# msno
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=  20170201  20170204         3
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=  20170201  20170211        11
# ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=  20170203  20170219        16
# ++0EzISdtKY48Z0GY62jer/LFQwrNIAbADdtU5xStGY=  20170201  20170205         5
# ++0d7elOGPXFeAuaDppOupFQa5ihSNTzHMNibE80qhI=  20170213  20170215         3
# ++37uKwAXaoPQVc2Qf0z5mYt/XaT/pGRSE23QyCX7kM=  20170203  20170206         4
# ++3A6JMzYJeron30GTcDostfXoAl8rTBuB2M8GeVdNU=  20170202  20170203         2
# ++3FD0IDUFeGFJBskYJYbJFJOxw/pduGN5BxfKFQvC4=  20170215  20170215         1
# ++3Z+W8OPnpbHYfrKwqRKN1bF83XEbxjdYUolhGdHZg=  20170227  20170227         1
# ++3wqX72HmowxFh5MrHvNi5Ce8D3ldo4zaUL932TYbs=  20170203  20170223        12
# ++4YWSlKw9vXYEFQ1qrldiSvwW/rVVP+rhaxAUcT8sc=  20170214  20170228        14
# ++4cUL0b9CfW8cj0A/wfSxQc4k4fcVtWcLqk2UOdpKs=  20170202  20170217        15
# ++57miEuSte1zcmehY9pZ1u9mZAqA3wX4h6CA5L17SA=  20170209  20170213         4
# ++5HPICzApqAq9mYdGB/mdke0MbubM8yUKLOmrPt4xU=  20170226  20170228         2
# ++60KS/9qGgIp/Lj9gERU7DH/5vKok+7GcJ3xccxBCI=  20170223  20170228         6
# ++6eU4LsQ3UQ20ILS7d99XK8WbiVgbyYL4FUgzZR134=  20170202  20170216        12
# ++7IULiyKbNc8jllqhRuyKZjX1J4mPF4tsudFCJfv4k=  20170221  20170228         8
# ++8dXbkKMJ0rXwUc/m19lTVokEl3c9EfRKWmV6qP9jg=  20170226  20170228         2
# ++95tJZADNg8U8HKbYdxbbXIRsO6pw1zBK4tHI7BtZo=  20170224  20170228         4
# ++A8p4GrsTnMjI6hAZEtlRsaz6s6O9ddUoH0fmS4s7s=  20170203  20170226         7
# ++BBU1qnsavj2eC5j5G6dTda9ntLhRiz+pidG73im5s=  20170201  20170220        12
# ++BW1PJYU5OZi3n3+IDLiU+d1IL1VE/GLx6p64TDs6U=  20170221  20170228         8
# ++Bks8kE9oclzxZM3hcWs+qzsxuoXFeIE1+7pxKBCQg=  20170201  20170212         8
# ++C60MuFnahjrKJq8Ai5w3vABSpprmg7szwbyaLMqo0=  20170204  20170204         1
# ++CUuTS4gPJbbTgS/WroA+ukwknUqdumkJxk0uiXGKg=  20170218  20170218         1
# ++DcyRE+ZfLtlKGigvv9dv5EQ4KAhHhiN9LM9X+F1vw=  20170228  20170228         1
# ++EX7OEtJz+hvd7VXRkcZINs+guDwpHq7ahe/o99E1o=  20170221  20170225         3
# ++FHWhbSrK+rHhHRClUmdqGJ1xsnytd3xBOUTO97LWs=  20170217  20170217         1
# ++FM6zdGj2whewSf10HHTRTeg2/jnxq3NQJKeYmAKwY=  20170204  20170219        16
# ++FojTWzKjhz7uxsZXEN3KBpxSmSvPr2j9KEuLzVAm4=  20170201  20170211        11
# ...                                                ...       ...       ...
# zznxIK74CmFA4ctJV0OdqizliOysqwVH3HYqSRatwjQ=  20170214  20170225        12
# zzo3871DFzsl0IYx9XpaQoGK0fj3xh2tZ6Z9qPkrVBY=  20170201  20170210         6
# zzoDlpMVa28r4EW18mzyEFDu/c/swxxeMPGLTinccc4=  20170202  20170226         7
# zzoaEw67A/0C1+4/RgRCBOVK+zsL1xJTMJMTdF42FxM=  20170201  20170203         3
# zzp++cVQOL+vApgAvHD7JtTt69oNArzMt0gWhVY7e1w=  20170206  20170228        14
# zzpTXKXmUXusfh8lgKDrPLEdQyNOvxl4a+PE0CwQIQU=  20170216  20170228        11
# zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=  20170223  20170228         6
# zzqhrI0gqPwQnjjWX4PC16TgaLSUwQaejWWeJjclfW8=  20170209  20170209         1
# zzrY1it2QC+CjK4sYzk2v2CBs/9omul7WWzlbyoyGqI=  20170207  20170207         1
# zzrbAK3qvnjXEc1KydPRiR/vhamJG07Ky853iZ1oshk=  20170219  20170228        10
# zzrd7DiMe4a9EIUBeIKSUxpblomhiBE3DvaC32fMl7o=  20170202  20170216        15
# zzsumtyPQEJN7XNakERtaZiXsGmc786aWSHFScPfV5k=  20170201  20170207         6
# zzt4LinfZVgufjQc8MVgTz9CwxB9pJtNJDnk3d3F7Ac=  20170208  20170223        15
# zztGcSZznx0uMBvc0fTQVTfCzeS7Ho/otO2L/4FXs/w=  20170204  20170206         2
# zztb7cCNxnkeZ33rHQ0Z3cnshdE8gn/nwMTiNP49b4o=  20170225  20170228         4
# zzuGxQfF86Zsx5nqF1Yh+oJpEIfdjFKKYpTqFZMdxzk=  20170208  20170227        11
# zzv/igs0VigNppe7WR8qgz1h6aXFFzQLu5paAswIbcQ=  20170208  20170226         4
# zzv2n8+r3LGI4gFp6c4hpseYdfHrl829IY3IlA0BF4Q=  20170201  20170204         4
# zzvB5JRK4WBwtKJoNtnNF34r5dUAuenPpR9xrxdfMSI=  20170214  20170219         3
# zzvhQSh5Xs6/9DO+wUTtEbSZRBHjGIpHMOP2kVMrXmk=  20170208  20170226        15
# zzvu4tofjH8jWZ4ubHaMr4K2AB7QARFwzJhcec3TxAU=  20170227  20170228         2
# zzx7wcys2Nha6yP2Skjs+R1/JNAfEuAWUaAp0qsV2Cg=  20170201  20170211         6
# zzxD9EdoP/qDco9fI92EpWHK/I7OV8rg9NMj2j9RA4c=  20170221  20170222         2
# zzxPS8+wCuE4HE85EDp4WBHgS5l548vfwXJbQq1HZ9I=  20170201  20170203         3
# zzxZeMFx2fjfKZigMnJa2w0EmloDbm8+8nTf/o/00GY=  20170201  20170225        10
# zzxqpgPX1epGyR3SVRKb3XitWdt+JqDURxV5ea1D7Cg=  20170201  20170215        12
# zzy0oyiTnRTo5Mbg23oKbBkf9eoaS7+eU4V+d14bzfY=  20170222  20170223         2
# zzy7iqSpfcRq7R4hmKKuhI+CJRs79a6pteqEggpiNO0=  20170202  20170216        15
# zzz1Dc3P9s53HAowRTrm3fNsWju5yeN4YBfNDq7Z99Q=  20170203  20170205         3
# zzzF1KsGfHH3qI6qiSNSXC35UXmVKMVFdxkp7xmDMc0=  20170205  20170210         4
#
#                                               num_tot_min  num_tot_max  \
# msno
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=            6           33
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=            5           50
# ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=            1           65
# ++0EzISdtKY48Z0GY62jer/LFQwrNIAbADdtU5xStGY=           28           54
# ++0d7elOGPXFeAuaDppOupFQa5ihSNTzHMNibE80qhI=            9           57
# ++37uKwAXaoPQVc2Qf0z5mYt/XaT/pGRSE23QyCX7kM=           92          370
# ++3A6JMzYJeron30GTcDostfXoAl8rTBuB2M8GeVdNU=            3           20
# ++3FD0IDUFeGFJBskYJYbJFJOxw/pduGN5BxfKFQvC4=            3            3
# ++3Z+W8OPnpbHYfrKwqRKN1bF83XEbxjdYUolhGdHZg=           62           62
# ++3wqX72HmowxFh5MrHvNi5Ce8D3ldo4zaUL932TYbs=            2           65
# ++4YWSlKw9vXYEFQ1qrldiSvwW/rVVP+rhaxAUcT8sc=            4           72
# ++4cUL0b9CfW8cj0A/wfSxQc4k4fcVtWcLqk2UOdpKs=            1          138
# ++57miEuSte1zcmehY9pZ1u9mZAqA3wX4h6CA5L17SA=           12           32
# ++5HPICzApqAq9mYdGB/mdke0MbubM8yUKLOmrPt4xU=            9           12
# ++60KS/9qGgIp/Lj9gERU7DH/5vKok+7GcJ3xccxBCI=            1           91
# ++6eU4LsQ3UQ20ILS7d99XK8WbiVgbyYL4FUgzZR134=            1           98
# ++7IULiyKbNc8jllqhRuyKZjX1J4mPF4tsudFCJfv4k=          148          205
# ++8dXbkKMJ0rXwUc/m19lTVokEl3c9EfRKWmV6qP9jg=            1           21
# ++95tJZADNg8U8HKbYdxbbXIRsO6pw1zBK4tHI7BtZo=            4           10
# ++A8p4GrsTnMjI6hAZEtlRsaz6s6O9ddUoH0fmS4s7s=            2           30
# ++BBU1qnsavj2eC5j5G6dTda9ntLhRiz+pidG73im5s=            2          112
# ++BW1PJYU5OZi3n3+IDLiU+d1IL1VE/GLx6p64TDs6U=           24           61
# ++Bks8kE9oclzxZM3hcWs+qzsxuoXFeIE1+7pxKBCQg=            3           62
# ++C60MuFnahjrKJq8Ai5w3vABSpprmg7szwbyaLMqo0=           21           21
# ++CUuTS4gPJbbTgS/WroA+ukwknUqdumkJxk0uiXGKg=            2            2
# ++DcyRE+ZfLtlKGigvv9dv5EQ4KAhHhiN9LM9X+F1vw=            2            2
# ++EX7OEtJz+hvd7VXRkcZINs+guDwpHq7ahe/o99E1o=           10           58
# ++FHWhbSrK+rHhHRClUmdqGJ1xsnytd3xBOUTO97LWs=           17           17
# ++FM6zdGj2whewSf10HHTRTeg2/jnxq3NQJKeYmAKwY=            3          110
# ++FojTWzKjhz7uxsZXEN3KBpxSmSvPr2j9KEuLzVAm4=            7           31
# ...                                                   ...          ...
# zznxIK74CmFA4ctJV0OdqizliOysqwVH3HYqSRatwjQ=            8           94
# zzo3871DFzsl0IYx9XpaQoGK0fj3xh2tZ6Z9qPkrVBY=            2           46
# zzoDlpMVa28r4EW18mzyEFDu/c/swxxeMPGLTinccc4=            1           91
# zzoaEw67A/0C1+4/RgRCBOVK+zsL1xJTMJMTdF42FxM=           59          136
# zzp++cVQOL+vApgAvHD7JtTt69oNArzMt0gWhVY7e1w=            1           54
# zzpTXKXmUXusfh8lgKDrPLEdQyNOvxl4a+PE0CwQIQU=            6           92
# zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=            9          129
# zzqhrI0gqPwQnjjWX4PC16TgaLSUwQaejWWeJjclfW8=            2            2
# zzrY1it2QC+CjK4sYzk2v2CBs/9omul7WWzlbyoyGqI=            8            8
# zzrbAK3qvnjXEc1KydPRiR/vhamJG07Ky853iZ1oshk=            9           64
# zzrd7DiMe4a9EIUBeIKSUxpblomhiBE3DvaC32fMl7o=           45          137
# zzsumtyPQEJN7XNakERtaZiXsGmc786aWSHFScPfV5k=            5           87
# zzt4LinfZVgufjQc8MVgTz9CwxB9pJtNJDnk3d3F7Ac=            2          117
# zztGcSZznx0uMBvc0fTQVTfCzeS7Ho/otO2L/4FXs/w=            7           47
# zztb7cCNxnkeZ33rHQ0Z3cnshdE8gn/nwMTiNP49b4o=           29          240
# zzuGxQfF86Zsx5nqF1Yh+oJpEIfdjFKKYpTqFZMdxzk=            3          123
# zzv/igs0VigNppe7WR8qgz1h6aXFFzQLu5paAswIbcQ=            4           45
# zzv2n8+r3LGI4gFp6c4hpseYdfHrl829IY3IlA0BF4Q=          110          185
# zzvB5JRK4WBwtKJoNtnNF34r5dUAuenPpR9xrxdfMSI=           17           82
# zzvhQSh5Xs6/9DO+wUTtEbSZRBHjGIpHMOP2kVMrXmk=            1          125
# zzvu4tofjH8jWZ4ubHaMr4K2AB7QARFwzJhcec3TxAU=           10           17
# zzx7wcys2Nha6yP2Skjs+R1/JNAfEuAWUaAp0qsV2Cg=            1           18
# zzxD9EdoP/qDco9fI92EpWHK/I7OV8rg9NMj2j9RA4c=            2            4
# zzxPS8+wCuE4HE85EDp4WBHgS5l548vfwXJbQq1HZ9I=           19           79
# zzxZeMFx2fjfKZigMnJa2w0EmloDbm8+8nTf/o/00GY=            2          117
# zzxqpgPX1epGyR3SVRKb3XitWdt+JqDURxV5ea1D7Cg=            2          101
# zzy0oyiTnRTo5Mbg23oKbBkf9eoaS7+eU4V+d14bzfY=            1            6
# zzy7iqSpfcRq7R4hmKKuhI+CJRs79a6pteqEggpiNO0=            9          107
# zzz1Dc3P9s53HAowRTrm3fNsWju5yeN4YBfNDq7Z99Q=            9           34
# zzzF1KsGfHH3qI6qiSNSXC35UXmVKMVFdxkp7xmDMc0=            6           33
#
#                                               num_tot_mean  f_lgt_min  \
# msno
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=     20.666667  -3.030505
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=     19.272727  -3.228556
# ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=     21.000000  -3.203813
# ++0EzISdtKY48Z0GY62jer/LFQwrNIAbADdtU5xStGY=     38.400000  -3.143193
# ++0d7elOGPXFeAuaDppOupFQa5ihSNTzHMNibE80qhI=     36.666667  -3.156218
# ++37uKwAXaoPQVc2Qf0z5mYt/XaT/pGRSE23QyCX7kM=    190.750000  -3.210212
# ++3A6JMzYJeron30GTcDostfXoAl8rTBuB2M8GeVdNU=     11.500000  -2.926947
# ++3FD0IDUFeGFJBskYJYbJFJOxw/pduGN5BxfKFQvC4=      3.000000  -2.980983
# ++3Z+W8OPnpbHYfrKwqRKN1bF83XEbxjdYUolhGdHZg=     62.000000  -2.993316
# ++3wqX72HmowxFh5MrHvNi5Ce8D3ldo4zaUL932TYbs=     24.916667  -3.051669
# ++4YWSlKw9vXYEFQ1qrldiSvwW/rVVP+rhaxAUcT8sc=     38.142857  -3.155562
# ++4cUL0b9CfW8cj0A/wfSxQc4k4fcVtWcLqk2UOdpKs=     80.533333  -3.237540
# ++57miEuSte1zcmehY9pZ1u9mZAqA3wX4h6CA5L17SA=     21.750000  -3.160921
# ++5HPICzApqAq9mYdGB/mdke0MbubM8yUKLOmrPt4xU=     10.500000  -3.028737
# ++60KS/9qGgIp/Lj9gERU7DH/5vKok+7GcJ3xccxBCI=     29.333333  -3.093786
# ++6eU4LsQ3UQ20ILS7d99XK8WbiVgbyYL4FUgzZR134=     44.333333  -3.248445
# ++7IULiyKbNc8jllqhRuyKZjX1J4mPF4tsudFCJfv4k=    175.625000  -3.303025
# ++8dXbkKMJ0rXwUc/m19lTVokEl3c9EfRKWmV6qP9jg=     11.000000  -3.079744
# ++95tJZADNg8U8HKbYdxbbXIRsO6pw1zBK4tHI7BtZo=      7.250000  -3.137669
# ++A8p4GrsTnMjI6hAZEtlRsaz6s6O9ddUoH0fmS4s7s=     12.571429  -3.155864
# ++BBU1qnsavj2eC5j5G6dTda9ntLhRiz+pidG73im5s=     48.833333  -3.228164
# ++BW1PJYU5OZi3n3+IDLiU+d1IL1VE/GLx6p64TDs6U=     39.625000  -3.226579
# ++Bks8kE9oclzxZM3hcWs+qzsxuoXFeIE1+7pxKBCQg=     19.000000  -3.271090
# ++C60MuFnahjrKJq8Ai5w3vABSpprmg7szwbyaLMqo0=     21.000000  -3.075131
# ++CUuTS4gPJbbTgS/WroA+ukwknUqdumkJxk0uiXGKg=      2.000000  -2.960839
# ++DcyRE+ZfLtlKGigvv9dv5EQ4KAhHhiN9LM9X+F1vw=      2.000000  -3.054663
# ++EX7OEtJz+hvd7VXRkcZINs+guDwpHq7ahe/o99E1o=     27.000000  -3.102603
# ++FHWhbSrK+rHhHRClUmdqGJ1xsnytd3xBOUTO97LWs=     17.000000  -3.059162
# ++FM6zdGj2whewSf10HHTRTeg2/jnxq3NQJKeYmAKwY=     42.500000  -3.148155
# ++FojTWzKjhz7uxsZXEN3KBpxSmSvPr2j9KEuLzVAm4=     17.545455  -3.204085
# ...                                                    ...        ...
# zznxIK74CmFA4ctJV0OdqizliOysqwVH3HYqSRatwjQ=     53.000000  -3.180147
# zzo3871DFzsl0IYx9XpaQoGK0fj3xh2tZ6Z9qPkrVBY=     17.666667  -3.172501
# zzoDlpMVa28r4EW18mzyEFDu/c/swxxeMPGLTinccc4=     28.714286  -3.047788
# zzoaEw67A/0C1+4/RgRCBOVK+zsL1xJTMJMTdF42FxM=    106.666667  -3.202655
# zzp++cVQOL+vApgAvHD7JtTt69oNArzMt0gWhVY7e1w=     14.642857  -3.098976
# zzpTXKXmUXusfh8lgKDrPLEdQyNOvxl4a+PE0CwQIQU=     41.363636  -3.072587
# zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=     67.500000  -3.238726
# zzqhrI0gqPwQnjjWX4PC16TgaLSUwQaejWWeJjclfW8=      2.000000  -3.055701
# zzrY1it2QC+CjK4sYzk2v2CBs/9omul7WWzlbyoyGqI=      8.000000  -3.107340
# zzrbAK3qvnjXEc1KydPRiR/vhamJG07Ky853iZ1oshk=     39.800000  -3.146319
# zzrd7DiMe4a9EIUBeIKSUxpblomhiBE3DvaC32fMl7o=     78.533333  -3.364704
# zzsumtyPQEJN7XNakERtaZiXsGmc786aWSHFScPfV5k=     40.166667  -3.149126
# zzt4LinfZVgufjQc8MVgTz9CwxB9pJtNJDnk3d3F7Ac=     27.733333  -3.232499
# zztGcSZznx0uMBvc0fTQVTfCzeS7Ho/otO2L/4FXs/w=     27.000000  -3.111277
# zztb7cCNxnkeZ33rHQ0Z3cnshdE8gn/nwMTiNP49b4o=    153.750000  -3.225284
# zzuGxQfF86Zsx5nqF1Yh+oJpEIfdjFKKYpTqFZMdxzk=     21.636364  -3.126775
# zzv/igs0VigNppe7WR8qgz1h6aXFFzQLu5paAswIbcQ=     23.250000  -3.092216
# zzv2n8+r3LGI4gFp6c4hpseYdfHrl829IY3IlA0BF4Q=    148.000000  -3.299910
# zzvB5JRK4WBwtKJoNtnNF34r5dUAuenPpR9xrxdfMSI=     55.333333  -3.176204
# zzvhQSh5Xs6/9DO+wUTtEbSZRBHjGIpHMOP2kVMrXmk=     44.466667  -3.201744
# zzvu4tofjH8jWZ4ubHaMr4K2AB7QARFwzJhcec3TxAU=     13.500000  -3.136878
# zzx7wcys2Nha6yP2Skjs+R1/JNAfEuAWUaAp0qsV2Cg=      8.500000  -3.318148
# zzxD9EdoP/qDco9fI92EpWHK/I7OV8rg9NMj2j9RA4c=      3.000000  -3.186363
# zzxPS8+wCuE4HE85EDp4WBHgS5l548vfwXJbQq1HZ9I=     48.000000  -3.161213
# zzxZeMFx2fjfKZigMnJa2w0EmloDbm8+8nTf/o/00GY=     42.400000  -3.215881
# zzxqpgPX1epGyR3SVRKb3XitWdt+JqDURxV5ea1D7Cg=     35.000000  -3.163889
# zzy0oyiTnRTo5Mbg23oKbBkf9eoaS7+eU4V+d14bzfY=      3.500000  -3.038925
# zzy7iqSpfcRq7R4hmKKuhI+CJRs79a6pteqEggpiNO0=     47.600000  -3.151495
# zzz1Dc3P9s53HAowRTrm3fNsWju5yeN4YBfNDq7Z99Q=     20.666667  -3.061860
# zzzF1KsGfHH3qI6qiSNSXC35UXmVKMVFdxkp7xmDMc0=     16.250000  -3.153339
#
#                                               f_lgt_max  f_lgt_mean  is_churn
# msno
# +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=  -2.990048   -3.005285       0.0
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=  -3.029553   -3.104501       0.0
# ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=  -2.746790   -3.037678       0.0
# ++0EzISdtKY48Z0GY62jer/LFQwrNIAbADdtU5xStGY=  -2.982562   -3.071827       0.0
# ++0d7elOGPXFeAuaDppOupFQa5ihSNTzHMNibE80qhI=  -2.880290   -3.031202       NaN
# ++37uKwAXaoPQVc2Qf0z5mYt/XaT/pGRSE23QyCX7kM=  -3.096206   -3.145230       NaN
# ++3A6JMzYJeron30GTcDostfXoAl8rTBuB2M8GeVdNU=  -2.903407   -2.915177       0.0
# ++3FD0IDUFeGFJBskYJYbJFJOxw/pduGN5BxfKFQvC4=  -2.980983   -2.980983       NaN
# ++3Z+W8OPnpbHYfrKwqRKN1bF83XEbxjdYUolhGdHZg=  -2.993316   -2.993316       0.0
# ++3wqX72HmowxFh5MrHvNi5Ce8D3ldo4zaUL932TYbs=  -2.820707   -2.912959       0.0
# ++4YWSlKw9vXYEFQ1qrldiSvwW/rVVP+rhaxAUcT8sc=  -2.919095   -3.038947       NaN
# ++4cUL0b9CfW8cj0A/wfSxQc4k4fcVtWcLqk2UOdpKs=  -3.047645   -3.131489       0.0
# ++57miEuSte1zcmehY9pZ1u9mZAqA3wX4h6CA5L17SA=  -3.068962   -3.109351       1.0
# ++5HPICzApqAq9mYdGB/mdke0MbubM8yUKLOmrPt4xU=  -2.988493   -3.008615       NaN
# ++60KS/9qGgIp/Lj9gERU7DH/5vKok+7GcJ3xccxBCI=  -2.626674   -2.994754       NaN
# ++6eU4LsQ3UQ20ILS7d99XK8WbiVgbyYL4FUgzZR134=  -2.713934   -3.037662       NaN
# ++7IULiyKbNc8jllqhRuyKZjX1J4mPF4tsudFCJfv4k=  -3.121871   -3.212898       0.0
# ++8dXbkKMJ0rXwUc/m19lTVokEl3c9EfRKWmV6qP9jg=  -3.046178   -3.062961       0.0
# ++95tJZADNg8U8HKbYdxbbXIRsO6pw1zBK4tHI7BtZo=  -3.041521   -3.081462       0.0
# ++A8p4GrsTnMjI6hAZEtlRsaz6s6O9ddUoH0fmS4s7s=  -2.854572   -2.997416       0.0
# ++BBU1qnsavj2eC5j5G6dTda9ntLhRiz+pidG73im5s=  -2.956851   -3.128234       0.0
# ++BW1PJYU5OZi3n3+IDLiU+d1IL1VE/GLx6p64TDs6U=  -3.075191   -3.137650       0.0
# ++Bks8kE9oclzxZM3hcWs+qzsxuoXFeIE1+7pxKBCQg=  -2.995251   -3.101975       0.0
# ++C60MuFnahjrKJq8Ai5w3vABSpprmg7szwbyaLMqo0=  -3.075131   -3.075131       NaN
# ++CUuTS4gPJbbTgS/WroA+ukwknUqdumkJxk0uiXGKg=  -2.960839   -2.960839       NaN
# ++DcyRE+ZfLtlKGigvv9dv5EQ4KAhHhiN9LM9X+F1vw=  -3.054663   -3.054663       1.0
# ++EX7OEtJz+hvd7VXRkcZINs+guDwpHq7ahe/o99E1o=  -3.013253   -3.049072       0.0
# ++FHWhbSrK+rHhHRClUmdqGJ1xsnytd3xBOUTO97LWs=  -3.059162   -3.059162       0.0
# ++FM6zdGj2whewSf10HHTRTeg2/jnxq3NQJKeYmAKwY=  -2.949451   -3.060730       NaN
# ++FojTWzKjhz7uxsZXEN3KBpxSmSvPr2j9KEuLzVAm4=  -3.081667   -3.145612       0.0
# ...                                                 ...         ...       ...
# zznxIK74CmFA4ctJV0OdqizliOysqwVH3HYqSRatwjQ=  -2.983902   -3.107707       0.0
# zzo3871DFzsl0IYx9XpaQoGK0fj3xh2tZ6Z9qPkrVBY=  -3.067313   -3.114872       NaN
# zzoDlpMVa28r4EW18mzyEFDu/c/swxxeMPGLTinccc4=  -2.675291   -2.920603       NaN
# zzoaEw67A/0C1+4/RgRCBOVK+zsL1xJTMJMTdF42FxM=  -3.154895   -3.174435       NaN
# zzp++cVQOL+vApgAvHD7JtTt69oNArzMt0gWhVY7e1w=  -2.841763   -2.991273       0.0
# zzpTXKXmUXusfh8lgKDrPLEdQyNOvxl4a+PE0CwQIQU=  -2.904875   -2.977326       0.0
# zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=  -3.064749   -3.120668       NaN
# zzqhrI0gqPwQnjjWX4PC16TgaLSUwQaejWWeJjclfW8=  -3.055701   -3.055701       0.0
# zzrY1it2QC+CjK4sYzk2v2CBs/9omul7WWzlbyoyGqI=  -3.107340   -3.107340       NaN
# zzrbAK3qvnjXEc1KydPRiR/vhamJG07Ky853iZ1oshk=  -2.971815   -3.084757       NaN
# zzrd7DiMe4a9EIUBeIKSUxpblomhiBE3DvaC32fMl7o=  -3.079664   -3.187197       0.0
# zzsumtyPQEJN7XNakERtaZiXsGmc786aWSHFScPfV5k=  -3.018006   -3.104227       1.0
# zzt4LinfZVgufjQc8MVgTz9CwxB9pJtNJDnk3d3F7Ac=  -2.939587   -3.085506       0.0
# zztGcSZznx0uMBvc0fTQVTfCzeS7Ho/otO2L/4FXs/w=  -2.988732   -3.050004       0.0
# zztb7cCNxnkeZ33rHQ0Z3cnshdE8gn/nwMTiNP49b4o=  -3.158742   -3.187466       NaN
# zzuGxQfF86Zsx5nqF1Yh+oJpEIfdjFKKYpTqFZMdxzk=  -3.009098   -3.062476       0.0
# zzv/igs0VigNppe7WR8qgz1h6aXFFzQLu5paAswIbcQ=  -2.933177   -3.032063       0.0
# zzv2n8+r3LGI4gFp6c4hpseYdfHrl829IY3IlA0BF4Q=  -3.205509   -3.246022       0.0
# zzvB5JRK4WBwtKJoNtnNF34r5dUAuenPpR9xrxdfMSI=  -3.073206   -3.140218       0.0
# zzvhQSh5Xs6/9DO+wUTtEbSZRBHjGIpHMOP2kVMrXmk=  -2.678579   -3.018713       0.0
# zzvu4tofjH8jWZ4ubHaMr4K2AB7QARFwzJhcec3TxAU=  -3.119421   -3.128149       NaN
# zzx7wcys2Nha6yP2Skjs+R1/JNAfEuAWUaAp0qsV2Cg=  -2.801497   -3.059296       1.0
# zzxD9EdoP/qDco9fI92EpWHK/I7OV8rg9NMj2j9RA4c=  -3.137025   -3.161694       NaN
# zzxPS8+wCuE4HE85EDp4WBHgS5l548vfwXJbQq1HZ9I=  -3.080119   -3.117178       0.0
# zzxZeMFx2fjfKZigMnJa2w0EmloDbm8+8nTf/o/00GY=  -2.891103   -3.110661       0.0
# zzxqpgPX1epGyR3SVRKb3XitWdt+JqDURxV5ea1D7Cg=  -2.919207   -3.039959       NaN
# zzy0oyiTnRTo5Mbg23oKbBkf9eoaS7+eU4V+d14bzfY=  -3.011240   -3.025083       NaN
# zzy7iqSpfcRq7R4hmKKuhI+CJRs79a6pteqEggpiNO0=  -2.934510   -3.077061       NaN
# zzz1Dc3P9s53HAowRTrm3fNsWju5yeN4YBfNDq7Z99Q=  -3.013153   -3.029617       0.0
# zzzF1KsGfHH3qI6qiSNSXC35UXmVKMVFdxkp7xmDMc0=  -3.055461   -3.089188       NaN
#
# [647155 rows x 10 columns]

# %%
srcg['dt_diff'] = srcg.dt_max - srcg.dt_min
srcg['dt_killer'] = 20170228 - srcg.dt_max
srcg['dt_avg'] = srcg.dt_diff / srcg.dt_count
srcg['ln_num_tot_diff'] = np.log(srcg.num_tot_max / srcg.num_tot_min)
srcg['ln_num_tot_mean'] = np.log(srcg.num_tot_mean)

# %%
plt.hist(srcg.dt_killer, bins=40)
plt.show()

# %%
tmpg = srcg.copy()
tmpg['g'] = np.floor(tmpg.dt_diff)
tmpg.groupby('g')['is_churn'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-246-12f91dc6f478> in <module>()
#       1 tmpg = srcg.copy()
#       2 tmpg['g'] = np.floor(tmpg.dt_diff)
# ----> 3 tmpg.groupby('g')['is_churn'].mean()
#
# C:\Anaconda3\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     352         else:
#     353             if key not in self.obj:
# --> 354                 raise KeyError("Column not found: %s" % key)
#     355             return self._gotitem(key, ndim=1)
#     356
#
# KeyError: 'Column not found: is_churn'
