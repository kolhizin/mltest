# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import datetime, time

from sklearn.linear_model import LinearRegression

import json
import re, pylev
from collections import Counter

def shuffleBatches(tensorTuple, batchSize=64):
    if type(tensorTuple) is list or type(tensorTuple) is tuple: 
        ids = list(range(tensorTuple[0].shape[0]))
        np.random.shuffle(ids)
        for i in range(0,len(ids),batchSize):
            lst = min(len(ids), i + batchSize)
            yield (np.array(x[ids[i:lst],]) for x in tensorTuple)
    else:
        ids = list(range(tensorTuple.shape[0]))
        np.random.shuffle(ids)
        for i in range(0,len(ids),batchSize):
            lst = min(len(ids), i + batchSize)
            yield np.array(tensorTuple[ids[i:lst],])
            
def forecast_timeleft(steps, times, final_step, alpha=0.1):
    if len(times) < 2:
        return 0
    vx = np.array(steps)
    vt = np.array(times)
    dx = vx[1:]-vx[:-1]
    dt = vt[1:]-vt[:-1]
    sx = vx[:-1]
    nf = 1 / np.mean(dx)
    nx = sx * nf
    dnx = dx * nf
    dtx = dt / dx
    wx0 = np.exp( - (nx[-1] - nx) * alpha)
    wx = wx0 / np.sum(wx0)
    
    y = dtx
    x = np.array([nx, dx])
    
  #  if(len(y) > 50):
  #      print(wx[-10:])
    
    lr = LinearRegression().fit(np.transpose(x), y, sample_weight = wx)
    
    res = 0
    for j in range(np.max(vx), final_step, int(1/nf)):
        xf = np.array([j*nf, 1]).reshape([1,2])
        res += lr.predict(xf)[0] / nf
    return res

# %%
src0 = pd.read_csv('../DataSets/UsedCars/autos_utf8.csv', low_memory=False)

# %%
rep_pattern = '[\+\\:;,\[\]\(\)]'
del_pattern = '[^a-z0-9_.]'
src1 = [re.sub(pattern=del_pattern, string=re.sub(pattern=rep_pattern, string=x.lower(), repl='_'), repl='') for x in list(src0.name) if type(x) is str]
src = [[y for y in x.split('_') if y != ''] for x in src1]

src_flat = [y for x in src for y in x]
src_count = list(dict(Counter(src_flat)).items())

# %%
src_fullness = [(i, sum([x[1] for x in src_pairs if x[1] > i])/len(src_flat), sum([1 for x in src_pairs if x[1]>i])) for i in range(100)]

# %%
#fix 5k dictionary size, which corresponds to at least 14 repeats of the word and 4.7% missing
#if 10k: at least 4 repeats and 2.7% missing
#if 2k: at least 60 repeats and 8.7% missin
#src_fullness[:50]

# %%
def word_prob(p1, p2, pow_base):
    low_err = abs(len(p1[0])-len(p2[0]))
    if np.power(pow_base, low_err) * float(p1[1] / p2[1]) > 1.0:
        return 1.0
    s1 = set(p1[0])
    s2 = set(p2[0])
    low_err = min(len(s1.difference(s2)), len(s2.difference(s1)))
    if np.power(pow_base, low_err) * float(p1[1] / p2[1]) > 1.0:
        return 1.0
    
    num_err = pylev.damerau_levenshtein(p1[0], p2[0])
    res = np.power(pow_base, num_err) * float(p1[1] / p2[1])
    
    #print(p1[0], ' - ', p2, ' / ', res)
    return res

def word_subs(p, plist):
    bestp = (p[0], p[1], 1)
    pow_base = max(10.0, 50.0 / min(10, len(p[0])))
    pow_basep = pow_base * p[1]
    for (i,p2) in enumerate(plist):
        if p2[1] < pow_basep:
            break
        if p[0] == p2[0]:
            continue
        prob = word_prob(p, p2, pow_base)
        if bestp is None or bestp[2] > prob:
            bestp = (p2[0], p2[1], prob)
    return bestp

# %%
r1_freq = 30
r1_mapper = {x:x for x,y in src_pairs if y >= r1_freq}
r1_mapper.update({x:'<UNK>' for x,y in src_pairs if y < r1_freq})
r1_src = [[r1_mapper[y] for y in x] for x in src]
r1_flat = [y for x in r1_src for y in x]

# %%
ts = []
for x in src_count[40000:40100]:
    t0 = time.perf_counter()
    for j in range(1):
        word_subs(x, src_count_s)
    t1 = time.perf_counter()
    ts.append((x, t1-t0))

# %%
[x for x in enumerate(ts) if x[1][1]>0.1]
# Out:
# [(17, (('ibizza', 1), 0.10464752308325842)),
#  (60, (('mann..', 1), 0.12278421697556041)),
#  (61, (('18535', 1), 0.10563904905575328)),
#  (63, (('20.600', 1), 0.10161857362254523)),
#  (79, (('vollvoll', 1), 0.11392920292564668))]

# %%
word_subs(src_count[40007], src_count_s)
# Out:
# eigentlich  -  ('bmw', 38077)  /  27.538303963
# eigentlich  -  ('volkswagen', 37411)  /  28.0285477533
# eigentlich  -  ('opel', 36017)  /  1.81958519588
# eigentlich  -  ('tdi', 33706)  /  1.9443422536
# eigentlich  -  ('audi', 31021)  /  8.45053350956
# eigentlich  -  ('mercedes', 30822)  /  8.50509376419
# eigentlich  -  ('golf', 30370)  /  2.15791899901
# eigentlich  -  ('2.0', 25774)  /  40.6834794754
# eigentlich  -  ('benz', 24650)  /  2.65866125761
# eigentlich  -  ('ford', 23843)  /  43.9783584281
# eigentlich  -  ('dpf', 19994)  /  52.44453336
# eigentlich  -  ('1.6', 19121)  /  54.8389728571
# eigentlich  -  ('mit', 18965)  /  3.45562878988
# eigentlich  -  ('renault', 15671)  /  4.18199221492
# eigentlich  -  ('polo', 13389)  /  19.5790574352
# eigentlich  -  ('klima', 13220)  /  4.95733736762
# eigentlich  -  ('tuev', 12864)  /  20.3781094527
# eigentlich  -  ('corsa', 12570)  /  83.4189339698
# eigentlich  -  ('automatik', 11387)  /  23.0213401247
# eigentlich  -  ('astra', 10790)  /  24.2950880445
# eigentlich  -  ('passat', 10409)  /  25.1843596887
# eigentlich  -  ('peugeot', 10262)  /  1.59656986942
# eigentlich  -  ('cabrio', 10050)  /  26.0839800995
# eigentlich  -  ('edition', 9137)  /  1.79314873591
# eigentlich  -  ('fiat', 9053)  /  7.23914724401
# eigentlich  -  ('sport', 8667)  /  30.2462212992
# eigentlich  -  ('navi', 8648)  /  7.57816836263
# eigentlich  -  ('kombi', 7935)  /  33.03642092
# eigentlich  -  ('zustand', 7612)  /  34.4382553862
# eigentlich  -  ('avant', 7550)  /  8.68026490066
# eigentlich  -  ('variant', 7245)  /  36.1827467219
# eigentlich  -  ('smart', 7178)  /  36.5204792421
# eigentlich  -  ('seat', 6795)  /  9.64473877851
# eigentlich  -  ('leder', 6503)  /  40.3112409657
# eigentlich  -  ('touring', 6416)  /  40.8578553616
# eigentlich  -  ('coupe', 6321)  /  165.887676001
# eigentlich  -  ('verkaufe', 6315)  /  41.5113222486
# eigentlich  -  ('diesel', 6050)  /  2.70809917355
# eigentlich  -  ('quattro', 6041)  /  43.394140043
# eigentlich  -  ('focus', 5924)  /  177.004726536
# eigentlich  -  ('xenon', 5672)  /  11.5543018336
# eigentlich  -  ('fiesta', 5654)  /  2.89777148921
# eigentlich  -  ('verkaufen', 5544)  /  189.137085137
# eigentlich  -  ('mazda', 5432)  /  193.036818851
# eigentlich  -  ('skoda', 5358)  /  195.702874207
# eigentlich  -  ('line', 5279)  /  12.414472438
# eigentlich  -  ('aut.', 5186)  /  50.5483995372
# eigentlich  -  ('twingo', 4880)  /  53.7180327869
# eigentlich  -  ('nissan', 4730)  /  55.421564482
# eigentlich  -  ('mini', 4613)  /  3.55170171255
# eigentlich  -  ('toyota', 4480)  /  58.5142857143
# eigentlich  -  ('highline', 4221)  /  0.970386164416
# eigentlich  -  ('tronic', 4212)  /  3.88983855651
# eigentlich  -  ('comfortline', 4206)  /  15.5815501664
# eigentlich  -  ('vectra', 4155)  /  15.7728038508
# eigentlich  -  ('avantgarde', 4002)  /  65.5032483758
# eigentlich  -  ('gepflegt', 3980)  /  4.11658291457
# eigentlich  -  ('elegance', 3893)  /  4.20857950167
# eigentlich  -  ('punto', 3713)  /  17.6504174522
# eigentlich  -  ('mondeo', 3536)  /  74.1357466063
# eigentlich  -  ('touran', 3445)  /  304.376197388
# eigentlich  -  ('paket', 3403)  /  19.2583014987
# eigentlich  -  ('hyundai', 3334)  /  19.6568686263
# eigentlich  -  ('caravan', 3252)  /  322.440344403
# eigentlich  -  ('volvo', 3199)  /  81.9456080025
# eigentlich  -  ('scheckheft', 3104)  /  84.4536082474
# eigentlich  -  ('zafira', 3039)  /  86.2599539322
# eigentlich  -  ('classic', 3029)  /  21.6361835589
# eigentlich  -  ('turbo', 2947)  /  88.9528333899
# eigentlich  -  ('citron', 2892)  /  22.6611341632
# eigentlich  -  ('megane', 2869)  /  22.8428023702
# eigentlich  -  ('bastler', 2865)  /  22.8746945899
# eigentlich  -  ('turnier', 2757)  /  23.7707653246
# eigentlich  -  ('honda', 2752)  /  95.2558139535
# eigentlich  -  ('mitsubishi', 2702)  /  24.2546262028
# eigentlich  -  ('tausch', 2638)  /  24.8430629265
# eigentlich  -  ('ibiza', 2625)  /  24.9660952381
# eigentlich  -  ('fortwo', 2497)  /  104.983580296
# eigentlich  -  ('bereift', 2397)  /  27.3408427201
# eigentlich  -  ('schwarz', 2362)  /  443.935647756
# eigentlich  -  ('style', 2354)  /  111.361087511
# eigentlich  -  ('cooper', 2318)  /  452.362381363
# eigentlich  -  ('combi', 2305)  /  113.728416486
# eigentlich  -  ('trendline', 2273)  /  1.80202375715
# eigentlich  -  ('sitzer', 2238)  /  29.2832886506
# eigentlich  -  ('porsche', 2236)  /  117.237924866
# eigentlich  -  ('suzuki', 2201)  /  119.102226261
# eigentlich  -  ('ambiente', 2187)  /  29.9661636946
# eigentlich  -  ('vollausstattung', 2172)  /  123589.06814
# eigentlich  -  ('servo', 2107)  /  124.415757
# eigentlich  -  ('comfort', 2066)  /  507.539206196
# eigentlich  -  ('fabia', 2053)  /  127.688261081
# eigentlich  -  ('klasse', 2029)  /  516.794480039
# eigentlich  -  ('gruene', 2027)  /  32.3315244203
# eigentlich  -  ('romeo', 2016)  /  130.031746032
# eigentlich  -  ('bluemotion', 2008)  /  32.6374501992
# eigentlich  -  ('octavia', 1991)  /  131.664490206
# eigentlich  -  ('plakette', 1978)  /  132.529828109
# eigentlich  -  ('gepflegter', 1943)  /  134.917138446
# eigentlich  -  ('suche', 1925)  /  136.178701299
# eigentlich  -  ('motor', 1899)  /  138.043180621
# eigentlich  -  ('cabriolet', 1879)  /  139.512506652
# eigentlich  -  ('benzin', 1857)  /  8.82283252558
# eigentlich  -  ('compact', 1826)  /  143.561883899
# eigentlich  -  ('facelift', 1813)  /  9.03695532267
# eigentlich  -  ('multivan', 1791)  /  146.367392518
# eigentlich  -  ('ambition', 1776)  /  36.9009009009
# eigentlich  -  ('blueefficiency', 1762)  /  2380.42224745
# eigentlich  -  ('citroen', 1750)  /  37.4491428571
# eigentlich  -  ('caddy', 1706)  /  614.640093787
# eigentlich  -  ('1.hand', 1699)  /  154.293113596
# eigentlich  -  ('micra', 1692)  /  154.93144208
# eigentlich  -  ('titanium', 1679)  /  9.75818939845
# eigentlich  -  ('chevrolet', 1643)  /  159.552038953
# eigentlich  -  ('limousine', 1615)  /  40.5795665635
# eigentlich  -  ('fahrbereit', 1587)  /  660.728418399
# eigentlich  -  ('sitzheizung', 1586)  /  661.145018916
# eigentlich  -  ('guter', 1580)  /  41.4784810127
# eigentlich  -  ('scenic', 1554)  /  2.63577863578
# eigentlich  -  ('exclusive', 1551)  /  42.2540296583
# eigentlich  -  ('sharan', 1540)  /  680.893506494
# eigentlich  -  ('grand', 1527)  /  171.672560576
# eigentlich  -  ('ausstattung', 1525)  /  687.590819672
# eigentlich  -  ('4motion', 1517)  /  43.2010547132
# eigentlich  -  ('garantie', 1477)  /  11.0927555856
# eigentlich  -  ('tausche', 1470)  /  178.329251701
# eigentlich  -  ('super', 1462)  /  179.30506156
# eigentlich  -  ('omega', 1443)  /  181.665973666
# eigentlich  -  ('tiptronic', 1413)  /  11.5951875442
# eigentlich  -  ('wenig', 1392)  /  11.7701149425
# eigentlich  -  ('standheizung', 1369)  /  3063.77209642
# eigentlich  -  ('schiebedach', 1361)  /  48.1528288024
# eigentlich  -  ('roadster', 1358)  /  193.036818851
# eigentlich  -  ('tuerer', 1353)  /  193.750184775
# eigentlich  -  ('rover', 1353)  /  193.750184775
# eigentlich  -  ('jahre', 1350)  /  776.722962963
# eigentlich  -  ('civic', 1323)  /  12.3839758125
# eigentlich  -  ('technology', 1319)  /  49.6861258529
# eigentlich  -  ('laguna', 1308)  /  50.1039755352
# eigentlich  -  ('trend', 1294)  /  50.6460587326
# eigentlich  -  ('multitronic', 1246)  /  210.388443018
# eigentlich  -  ('klimaautomatik', 1239)  /  13540.9330105
# eigentlich  -  ('bastlerfahrzeug', 1236)  /  217180.789644
# eigentlich  -  ('chrysler', 1214)  /  215.934102142
# eigentlich  -  ('transporter', 1204)  /  3483.64119601
# eigentlich  -  ('panorama', 1200)  /  218.453333333
# eigentlich  -  ('gegen', 1170)  /  14.0034188034
# eigentlich  -  ('gasanlage', 1153)  /  56.8395490026
# eigentlich  -  ('galaxy', 1152)  /  56.8888888889
# eigentlich  -  ('passion', 1119)  /  234.266309205
# eigentlich  -  ('sportline', 1081)  /  15.1563367253
# eigentlich  -  ('oldtimer', 1059)  /  247.539187913
# eigentlich  -  ('meriva', 1047)  /  62.594078319
# eigentlich  -  ('motorschaden', 1046)  /  16039.4034417
# eigentlich  -  ('tempomat', 1036)  /  253.034749035
# eigentlich  -  ('klimaanlage', 1031)  /  254.261881668
# eigentlich  -  ('silber', 1025)  /  63.9375609756
# eigentlich  -  ('original', 1013)  /  16.1737413623
# eigentlich  -  ('unfallfrei', 1012)  /  1036.14229249
# eigentlich  -  ('4matic', 1009)  /  16.2378592666
# eigentlich  -  ('zahnriemen', 1003)  /  1045.43968096
# eigentlich  -  ('zulassung', 988)  /  1061.31174089
# eigentlich  -  ('tuerig', 914)  /  71.7024070022
# eigentlich  -  ('alufelgen', 910)  /  288.07032967
# eigentlich  -  ('schoener', 907)  /  289.023153252
# eigentlich  -  ('kangoo', 897)  /  292.245261984
# eigentlich  -  ('tiguan', 894)  /  73.3064876957
# eigentlich  -  ('ausschlachten', 889)  /  1179.50056243
# eigentlich  -  ('corolla', 885)  /  296.207909605
# eigentlich  -  ('benziner', 868)  /  75.5023041475
# eigentlich  -  ('tourer', 867)  /  1209.43021915
# eigentlich  -  ('tuning', 842)  /  77.8337292162
# eigentlich  -  ('unfall', 837)  /  313.19474313
# eigentlich  -  ('beetle', 825)  /  19.8593939394
# eigentlich  -  ('moeglich', 815)  /  1.25644171779
# eigentlich  -  ('2.hand', 814)  /  322.044226044
# eigentlich  -  ('modell', 813)  /  80.6100861009
# eigentlich  -  ('escort', 799)  /  82.0225281602
# eigentlich  -  ('berlingo', 794)  /  82.5390428212
# eigentlich  -  ('active', 777)  /  84.3449163449
# eigentlich  -  ('attraction', 776)  /  337.81443299
# eigentlich  -  ('faltdach', 775)  /  21.1406451613
# eigentlich  -  ('sports', 731)  /  358.610123119
# eigentlich  -  ('transit', 724)  /  90.5193370166
# eigentlich  -  ('special', 723)  /  90.6445366528
# eigentlich  -  ('executive', 722)  /  22.6925207756
# eigentlich  -  ('ecoflex', 717)  /  91.4030683403
# eigentlich  -  ('touareg', 716)  /  1464.49162011
# eigentlich  -  ('grande', 712)  /  368.179775281
# eigentlich  -  ('limited', 710)  /  92.3042253521
# eigentlich  -  ('allrad', 703)  /  372.893314367
# eigentlich  -  ('meinen', 701)  /  23.3723252496
# eigentlich  -  ('metallic', 701)  /  23.3723252496
# eigentlich  -  ('daihatsu', 694)  /  377.729106628
# eigentlich  -  ('insignia', 690)  /  94.9797101449
# eigentlich  -  ('sprinter', 689)  /  95.1175616836
# eigentlich  -  ('kleinwagen', 688)  /  381.023255814
# eigentlich  -  ('getriebe', 683)  /  23.9882869693
# eigentlich  -  ('motion', 683)  /  95.953147877
# eigentlich  -  ('family', 661)  /  396.58698941
# eigentlich  -  ('caravelle', 655)  /  400.219847328
# eigentlich  -  ('extras', 653)  /  100.361408882
# eigentlich  -  ('espace', 652)  /  100.515337423
# eigentlich  -  ('1.9tdi', 634)  /  103.369085174
# eigentlich  -  ('abzugeben', 629)  /  1667.05246423
# eigentlich  -  ('scirocco', 617)  /  424.868719611
# eigentlich  -  ('export', 615)  /  106.562601626
# eigentlich  -  ('individual', 601)  /  1744.718802
# eigentlich  -  ('jaguar', 597)  /  439.102177554
# eigentlich  -  ('platinum', 595)  /  440.578151261
# eigentlich  -  ('seicento', 585)  /  7.00170940171
# eigentlich  -  ('united', 581)  /  451.194492255
# eigentlich  -  ('softouch', 577)  /  28.3951473137
# eigentlich  -  ('primera', 574)  /  456.696864111
# eigentlich  -  ('defekt', 562)  /  116.612099644
# eigentlich  -  ('felgen', 560)  /  29.2571428571
# eigentlich  -  ('almera', 559)  /  468.951699463
# eigentlich  -  ('autogas', 555)  /  472.331531532
# eigentlich  -  ('premium', 552)  /  118.724637681
# eigentlich  -  ('avensis', 548)  /  29.897810219
# eigentlich  -  ('trabant', 546)  /  480.117216117
# eigentlich  -  ('kilometer', 544)  /  481.882352941
# eigentlich  -  ('reifen', 513)  /  31.9376218324
# eigentlich  -  ('qashqai', 512)  /  512.0
# eigentlich  -  ('selection', 511)  /  32.0626223092
# eigentlich  -  ('futura', 507)  /  517.049309665
# eigentlich  -  ('schlachtfest', 500)  /  8388.608
# eigentlich  -  ('neuteile', 492)  /  33.3008130081
# eigentlich  -  ('signum', 491)  /  33.3686354379
# eigentlich  -  ('dynamic', 491)  /  33.3686354379
# eigentlich  -  ('2.0tdi', 489)  /  134.020449898
# eigentlich  -  ('packet', 484)  /  541.619834711
# eigentlich  -  ('picasso', 478)  /  548.418410042
# eigentlich  -  ('cherokee', 466)  /  562.540772532
# eigentlich  -  ('lancia', 460)  /  142.469565217
# eigentlich  -  ('kaefer', 457)  /  573.619256018
# eigentlich  -  ('winterreifen', 449)  /  583.839643653
# eigentlich  -  ('festpreis', 446)  /  587.766816143
# eigentlich  -  ('guenstig', 440)  /  37.2363636364
# eigentlich  -  ('vollleder', 439)  /  2388.55580866
# eigentlich  -  ('kupplung', 435)  /  602.629885057
# eigentlich  -  ('innovation', 435)  /  602.629885057
# eigentlich  -  ('multijet', 428)  /  612.485981308
# eigentlich  -  ('service', 423)  /  38.7328605201
# eigentlich  -  ('daewoo', 421)  /  622.669833729
# eigentlich  -  ('automatic', 419)  /  156.410501193
# eigentlich  -  ('102017', 419)  /  2502.56801909
# eigentlich  -  ('xdrive', 414)  /  633.198067633
# eigentlich  -  ('kamera', 412)  /  636.27184466
# eigentlich  -  ('ducato', 411)  /  637.819951338
# eigentlich  -  ('cayenne', 403)  /  162.620347395
# eigentlich  -  ('schlachten', 402)  /  2608.39800995
# eigentlich  -  ('alhambra', 393)  /  2668.13231552
# eigentlich  -  ('vitara', 389)  /  168.473007712
# eigentlich  -  ('syncro', 389)  /  673.892030848
# eigentlich  -  ('reserviert', 388)  /  675.628865979
# eigentlich  -  ('tueren', 388)  /  675.628865979
# eigentlich  -  ('kadett', 386)  /  169.78238342
# eigentlich  -  ('carrera', 386)  /  2716.51813472
# eigentlich  -  ('112017', 386)  /  2716.51813472
# eigentlich  -  ('anfaengerauto', 384)  /  10922.6666667
# eigentlich  -  ('unfallwagen', 382)  /  10979.8534031
# eigentlich  -  ('privat', 381)  /  688.041994751
# eigentlich  -  ('cruiser', 376)  /  2788.76595745
# eigentlich  -  ('lounge', 371)  /  706.587601078
# eigentlich  -  ('allroad', 363)  /  2888.63911846
# eigentlich  -  ('inspektion', 363)  /  180.539944904
# eigentlich  -  ('carisma', 362)  /  2896.61878453
# eigentlich  -  ('sommer', 360)  /  2912.71111111
# eigentlich  -  ('anfaenger', 359)  /  730.206128134
# eigentlich  -  ('ecoboost', 358)  /  732.245810056
# eigentlich  -  ('vollaustattung', 356)  /  188508.044944
# eigentlich  -  ('andere', 354)  /  740.519774011
# eigentlich  -  ('picanto', 354)  /  46.2824858757
# eigentlich  -  ('tauschen', 351)  /  2987.3960114
# eigentlich  -  ('acenta', 351)  /  46.6780626781
# eigentlich  -  ('sorento', 347)  /  47.2161383285
# eigentlich  -  ('accord', 346)  /  3030.56647399
# eigentlich  -  ('keyless', 337)  /  194.46884273
# eigentlich  -  ('toledo', 337)  /  777.87537092
# eigentlich  -  ('kasten', 336)  /  780.19047619
# eigentlich  -  ('fenster', 336)  /  195.047619048
# eigentlich  -  ('authentique', 331)  /  197.993957704
# eigentlich  -  ('vivaro', 330)  /  794.375757576
# eigentlich  -  ('teilleder', 329)  /  796.790273556
# eigentlich  -  ('022018', 328)  /  3196.87804878
# eigentlich  -  ('technisch', 324)  /  50.5679012346
# eigentlich  -  ('alcantara', 322)  /  203.527950311
# eigentlich  -  ('hybrid', 321)  /  816.647975078
# eigentlich  -  ('anlage', 315)  /  208.050793651
# eigentlich  -  ('122017', 315)  /  3328.81269841
# eigentlich  -  ('tendance', 315)  /  52.0126984127
# eigentlich  -  ('bertone', 315)  /  208.050793651
# eigentlich  -  ('navigation', 310)  /  211.406451613
# eigentlich  -  ('youngtimer', 308)  /  851.116883117
# eigentlich  -  ('angemeldet', 308)  /  53.1948051948
# eigentlich  -  ('angebot', 307)  /  213.472312704
# eigentlich  -  ('forfour', 302)  /  3472.10596026
# eigentlich  -  ('kennzeichen', 300)  /  218.453333333
# eigentlich  -  ('gepflegten', 295)  /  888.623728814
# eigentlich  -  ('fusion', 293)  /  894.689419795
# eigentlich  -  ('gepflegtes', 290)  /  903.944827586
# eigentlich  -  ('zylinder', 287)  /  913.393728223
# eigentlich  -  ('mustang', 287)  /  913.393728223
# eigentlich  -  ('esprit', 286)  /  229.146853147
# eigentlich  -  ('072017', 286)  /  3666.34965035
# eigentlich  -  ('design', 283)  /  231.575971731
# eigentlich  -  ('generation', 279)  /  234.896057348
# eigentlich  -  ('bremsen', 277)  /  946.368231047
# eigentlich  -  ('kastenwagen', 276)  /  949.797101449
# eigentlich  -  ('autotronic', 275)  /  953.250909091
# eigentlich  -  ('pritsche', 275)  /  238.312727273
# eigentlich  -  ('herrichten', 273)  /  960.234432234
# eigentlich  -  ('roomster', 272)  /  963.764705882
# eigentlich  -  ('concept', 272)  /  963.764705882
# eigentlich  -  ('privilege', 270)  /  970.903703704
# eigentlich  -  ('california', 269)  /  3898.05204461
# eigentlich  -  ('gelaufen', 268)  /  244.537313433
# eigentlich  -  ('garagenwagen', 267)  /  981.812734082
# eigentlich  -  ('tuevau', 264)  /  992.96969697
# eigentlich  -  ('vielen', 262)  /  62.534351145
# eigentlich  -  ('unfallschaden', 262)  /  16008.7938931
# eigentlich  -  ('102016', 262)  /  4002.19847328
# eigentlich  -  ('sporting', 257)  /  255.003891051
# eigentlich  -  ('pacific', 255)  /  257.003921569
# eigentlich  -  ('multispace', 252)  /  1040.25396825
# eigentlich  -  ('checkheft', 248)  /  1057.03225806
# eigentlich  -  ('easytronic', 243)  /  269.695473251
# eigentlich  -  ('carnival', 243)  /  1078.781893
# eigentlich  -  ('limosine', 237)  /  276.523206751
# eigentlich  -  ('reference', 235)  /  278.876595745
# eigentlich  -  ('flitzer', 229)  /  1144.73362445
# eigentlich  -  ('maengel', 227)  /  288.704845815
# eigentlich  -  ('liebhaber', 227)  /  288.704845815
# eigentlich  -  ('schnaeppchen', 223)  /  4702.13452915
# eigentlich  -  ('partner', 223)  /  1175.53363229
# eigentlich  -  ('kleiner', 221)  /  1186.1719457
# eigentlich  -  ('initiale', 215)  /  304.818604651
# eigentlich  -  ('phaeton', 213)  /  307.680751174
# eigentlich  -  ('calibra', 213)  /  1230.72300469
# eigentlich  -  ('lifestyle', 212)  /  77.2830188679
# eigentlich  -  ('schlachte', 209)  /  1254.27751196
# eigentlich  -  ('nichtraucher', 205)  /  1278.75121951
# eigentlich  -  ('business', 205)  /  1278.75121951
# eigentlich  -  ('schalter', 204)  /  1285.01960784
# eigentlich  -  ('einzelstueck', 200)  /  81.92
# eigentlich  -  ('momentum', 199)  /  82.3316582915
# eigentlich  -  ('connect', 196)  /  334.367346939
# eigentlich  -  ('gesucht', 195)  /  84.0205128205
# eigentlich  -  ('distinctive', 193)  /  339.564766839
# eigentlich  -  ('erhaltener', 189)  /  346.751322751
# eigentlich  -  ('college', 187)  /  1401.83957219
# eigentlich  -  ('dringend', 184)  /  356.173913043
# eigentlich  -  ('schaden', 181)  /  5793.23756906
# eigentlich  -  ('cinquecento', 179)  /  5857.96648045
# eigentlich  -  ('liberty', 179)  /  91.530726257
# eigentlich  -  ('confort', 178)  /  1472.71910112
# eigentlich  -  ('bluetooth', 178)  /  92.0449438202
# eigentlich  -  ('orginal', 176)  /  93.0909090909
# eigentlich  -  ('captiva', 168)  /  390.095238095
# eigentlich  -  ('wrangler', 167)  /  392.431137725
# eigentlich  -  ('schoenes', 167)  /  1569.7245509
# eigentlich  -  ('klimatronic', 166)  /  1579.18072289
# eigentlich  -  ('bluetec', 164)  /  99.9024390244
# eigentlich  -  ('rentner', 161)  /  101.763975155
# eigentlich  -  ('einparkhilfe', 161)  /  1628.22360248
# eigentlich  -  ('laureate', 159)  /  1648.70440252
# eigentlich  -  ('elektr.', 159)  /  103.044025157
# eigentlich  -  ('schoenen', 156)  /  1680.41025641
# eigentlich  -  ('glasdach', 155)  /  105.703225806
# eigentlich  -  ('fahranfaenger', 151)  /  111107.390728
# eigentlich  -  ('avantage', 150)  /  436.906666667
# eigentlich  -  ('erhalten', 148)  /  442.810810811
# eigentlich  -  ('austattung', 147)  /  1783.29251701
# eigentlich  -  ('felicia', 146)  /  112.219178082
# eigentlich  -  ('corvette', 145)  /  1807.88965517
# eigentlich  -  ('frontschaden', 145)  /  7231.55862069
# eigentlich  -  ('neuwertig', 145)  /  112.993103448
# eigentlich  -  ('plakete', 144)  /  1820.44444444
# eigentlich  -  ('cadillac', 143)  /  458.293706294
# eigentlich  -  ('gelaendewagen', 142)  /  7384.33802817
# eigentlich  -  ('barchetta', 141)  /  7436.70921986
# eigentlich  -  ('advantage', 141)  /  464.794326241
# eigentlich  -  ('gruener', 140)  /  468.114285714
# eigentlich  -  ('ecomotive', 139)  /  117.870503597
# eigentlich  -  ('technik', 137)  /  478.364963504
# eigentlich  -  ('gebraucht', 136)  /  120.470588235
# eigentlich  -  ('weekend', 135)  /  485.451851852
# eigentlich  -  ('starlet', 135)  /  1941.80740741
# eigentlich  -  ('defender', 135)  /  485.451851852
# eigentlich  -  ('climatronic', 132)  /  1985.93939394
# eigentlich  -  ('familienauto', 129)  /  8128.49612403
# eigentlich  -  ('prestige', 127)  /  129.007874016
# eigentlich  -  ('extralang', 124)  /  528.516129032
# eigentlich  -  ('5tuerer', 123)  /  2131.25203252
# eigentlich  -  ('stylance', 123)  /  2131.25203252
# eigentlich  -  ('traveller', 123)  /  2131.25203252
# eigentlich  -  ('atlantis', 123)  /  133.203252033
# eigentlich  -  ('irmscher', 121)  /  2166.47933884
# eigentlich  -  ('zentral', 119)  /  137.680672269
# eigentlich  -  ('ecofuel', 117)  /  560.136752137
# eigentlich  -  ('familien', 117)  /  560.136752137
# eigentlich  -  ('anbieten', 117)  /  2240.54700855
# eigentlich  -  ('schoene', 116)  /  2259.86206897
# eigentlich  -  ('technology...', 116)  /  36157.7931034
# eigentlich  -  ('teiletraeger', 113)  /  2319.85840708
# eigentlich  -  ('rolling', 113)  /  579.96460177
# eigentlich  -  ('tourneo', 112)  /  2340.57142857
# eigentlich  -  ('pontiac', 112)  /  146.285714286
# eigentlich  -  ('teilespender', 110)  /  2383.12727273
# eigentlich  -  ('advance', 110)  /  595.781818182
# eigentlich  -  ('kleines', 110)  /  2383.12727273
# eigentlich  -  ('twintop', 110)  /  595.781818182
# eigentlich  -  ('gewinde', 107)  /  612.485981308
# eigentlich  -  ('anhaenger', 106)  /  2473.05660377
# eigentlich  -  ('exception', 105)  /  39.0095238095
# eigentlich  -  ('bixenon', 105)  /  156.038095238
# eigentlich  -  ('terracan', 104)  /  2520.61538462
# eigentlich  -  ('crafter', 104)  /  2520.61538462
# eigentlich  -  ('raritaet', 103)  /  2545.08737864
# eigentlich  -  ('designo', 103)  /  636.27184466
# eigentlich  -  ('schicker', 101)  /  10381.9405941
# eigentlich  -  ('atlanta', 101)  /  648.871287129
# eigentlich  -  ('erstzulassung', 101)  /  41527.7623762
# eigentlich  -  ('langversion', 100)  /  2621.44
# eigentlich  -  ('startline', 99)  /  165.494949495
# eigentlich  -  ('hochdach', 98)  /  668.734693878
# eigentlich  -  ('5tuerig', 96)  /  682.666666667
# eigentlich  -  ('emotion', 96)  /  170.666666667
# eigentlich  -  ('citroeen', 94)  /  2788.76595745
# eigentlich  -  ('kleinen', 92)  /  712.347826087
# eigentlich  -  ('anschauen', 92)  /  11397.5652174
# eigentlich  -  ('sportlich', 91)  /  11.2527472527
# eigentlich  -  ('styling', 90)  /  728.177777778
# eigentlich  -  ('sebring', 90)  /  728.177777778
# eigentlich  -  ('gepflegte', 90)  /  728.177777778
# eigentlich  -  ('cricket', 90)  /  2912.71111111
# eigentlich  -  ('collection', 90)  /  728.177777778
# eigentlich  -  ('grosses', 89)  /  2945.43820225
# eigentlich  -  ('guenstiger', 89)  /  736.359550562
# eigentlich  -  ('kinetic', 88)  /  11.6363636364
# eigentlich  -  ('achtung', 88)  /  2978.90909091
# eigentlich  -  ('station', 88)  /  744.727272727
# eigentlich  -  ('gemacht', 87)  /  188.32183908
# eigentlich  -  ('gepflegt.', 86)  /  762.046511628
# eigentlich  -  ('ferrari', 84)  /  3120.76190476
# eigentlich  -  ('elektrische', 84)  /  48.7619047619
# eigentlich  -  ('ideales', 84)  /  195.047619048
# eigentlich  -  ('rechtslenker', 83)  /  50533.7831325
# eigentlich  -  ('intense', 83)  /  197.397590361
# eigentlich  -  ('pluriel', 82)  /  3196.87804878
# eigentlich  -  ('courier', 82)  /  3196.87804878
# eigentlich  -  ('hingucker', 82)  /  3196.87804878
# eigentlich  -  ('deutsches', 82)  /  799.219512195
# eigentlich  -  ('conceptline', 81)  /  202.271604938
# eigentlich  -  ('ambiance', 81)  /  3236.34567901
# eigentlich  -  ('standheiz', 79)  /  3318.27848101
# eigentlich  -  ('schnitzer', 78)  /  3360.82051282
# eigentlich  -  ('werksgarantie', 78)  /  13443.2820513
# eigentlich  -  ('sitzhzg', 78)  /  840.205128205
# eigentlich  -  ('steilheck', 77)  /  851.116883117
# eigentlich  -  ('zweitwagen', 77)  /  3404.46753247
# eigentlich  -  ('eclipse', 76)  /  862.315789474
# eigentlich  -  ('terrano', 75)  /  3495.25333333
# eigentlich  -  ('sportlicher', 75)  /  218.453333333
# eigentlich  -  ('ratenzahlung', 75)  /  3495.25333333
# eigentlich  -  ('scheckh.', 74)  /  3542.48648649
# eigentlich  -  ('schrott', 74)  /  3542.48648649
# eigentlich  -  ('eingetragen', 74)  /  221.405405405
# eigentlich  -  ('schiebetueren', 73)  /  57456.2191781
# eigentlich  -  ('fahrtuechtig', 71)  /  14768.6760563
# eigentlich  -  ('optisch', 71)  /  230.76056338
# eigentlich  -  ('twinair', 70)  /  936.228571429
# eigentlich  -  ('monaten', 70)  /  3744.91428571
# eigentlich  -  ('airmatic', 69)  /  59.3623188406
# eigentlich  -  ('familie', 69)  /  949.797101449
# eigentlich  -  ('satellite', 69)  /  237.449275362
# eigentlich  -  ('airride', 68)  /  963.764705882
# eigentlich  -  ('papiere', 68)  /  15420.2352941
# eigentlich  -  ('stronic', 68)  /  240.941176471
# eigentlich  -  ('unseren', 68)  /  3855.05882353
# eigentlich  -  ('evolution', 67)  /  244.537313433
# eigentlich  -  ('caliber', 67)  /  3912.59701493
# eigentlich  -  ('xenonlicht', 67)  /  61.1343283582
# eigentlich  -  ('gebrauchter', 66)  /  3971.87878788
# eigentlich  -  ('gelegenheit', 66)  /  248.242424242
# eigentlich  -  ('4tuerig', 66)  /  992.96969697
# eigentlich  -  ('selespeed', 65)  /  4032.98461538
# eigentlich  -  ('gefahren', 65)  /  1008.24615385
# eigentlich  -  ('syste...', 65)  /  4032.98461538
# eigentlich  -  ('maschine', 64)  /  4096.0
# eigentlich  -  ('schaltung', 64)  /  4096.0
# eigentlich  -  ('neuwagen', 64)  /  4096.0
# eigentlich  -  ('seltener', 63)  /  1040.25396825
# eigentlich  -  ('kurvenlicht', 61)  /  67.1475409836
# eigentlich  -  ('guenstiges', 61)  /  1074.36065574
# eigentlich  -  ('schnppchen', 58)  /  4519.72413793
# eigentlich  -  ('giulietta', 56)  /  4681.14285714
# eigentlich  -  ('maengeln', 56)  /  1170.28571429
# eigentlich  -  ('efficiency', 53)  /  1236.52830189
# eigentlich  -  ('geliebten', 53)  /  1236.52830189
# eigentlich  -  ('interieur', 52)  /  1260.30769231
# eigentlich  -  ('laufleistung', 51)  /  82241.254902
# eigentlich  -  ('geartronic', 51)  /  1285.01960784
# eigentlich  -  ('gutachten', 51)  /  5140.07843137
# eigentlich  -  ('erneuert', 51)  /  1285.01960784
# eigentlich  -  ('erhaltenen', 50)  /  1310.72
# eigentlich  -  ('techno...', 50)  /  5242.88
# eigentlich  -  ('neuteilen', 50)  /  1310.72
# eigentlich  -  ('econetic', 50)  /  20.48
# eigentlich  -  ('schaltwippen', 50)  /  20971.52
# eigentlich  -  ('ringtool', 48)  /  1365.33333333
# eigentlich  -  ('totalschaden', 46)  /  91180.5217391
# eigentlich  -  ('sitzheitzung', 45)  /  5825.42222222
# eigentlich  -  ('chiemsee', 45)  /  5825.42222222
# eigentlich  -  ('leichter', 45)  /  1456.35555556
# eigentlich  -  ('sitzheiz', 45)  /  1456.35555556
# eigentlich  -  ('gerissen', 44)  /  1489.45454545
# eigentlich  -  ('langstrecke', 44)  /  5957.81818182
# eigentlich  -  ('efficient', 42)  /  1560.38095238
# eigentlich  -  ('hagelschaden', 41)  /  6393.75609756
# eigentlich  -  ('beschreibung', 41)  /  102300.097561
# eigentlich  -  ('cleartec', 40)  /  1638.4
# eigentlich  -  ('schlachtung', 40)  /  104857.6
# eigentlich  -  ('tagfahrlicht', 38)  /  431.157894737
# eigentlich  -  ('gewechselt', 38)  /  6898.52631579
# eigentlich  -  ('eventuell', 35)  /  117.028571429
# eigentlich  -  ('essentia', 35)  /  29.2571428571
# eigentlich  -  ('fahrtauglich', 34)  /  1927.52941176
# eigentlich  -  ('guenstige', 32)  /  512.0
# eigentlich  -  ('fruehling', 31)  /  528.516129032
# eigentlich  -  ('polnische', 31)  /  2114.06451613
# eigentlich  -  ('scheiben', 30)  /  8738.13333333
# eigentlich  -  ('einzelstck', 30)  /  546.133333333
# eigentlich  -  ('kopfdichtung', 30)  /  139810.133333
# eigentlich  -  ('einsteigen', 30)  /  546.133333333
# eigentlich  -  ('lichtpaket', 29)  /  9039.44827586
# eigentlich  -  ('tiefergelegt', 29)  /  9039.44827586
# eigentlich  -  ('continental', 29)  /  9039.44827586
# eigentlich  -  ('lwechsel', 29)  /  9039.44827586
# eigentlich  -  ('technolo...', 29)  /  9039.44827586
# eigentlich  -  ('greenline', 28)  /  146.285714286
# eigentlich  -  ('schalensitze', 28)  /  37449.1428571
# eigentlich  -  ('geschlossen', 27)  /  38836.1481481
# eigentlich  -  ('moeglich.', 27)  /  151.703703704
# eigentlich  -  ('baugleich', 26)  /  630.153846154
# eigentlich  -  ('classicline', 26)  /  10082.4615385
# eigentlich  -  ('elektrisches', 26)  /  630.153846154
# eigentlich  -  ('highclass', 26)  /  630.153846154
# eigentlich  -  ('langstrecken', 26)  /  40329.8461538
# eigentlich  -  ('techn....', 25)  /  10485.76
# eigentlich  -  ('technologie', 25)  /  10485.76
# eigentlich  -  ('handschalter', 24)  /  174762.666667
# eigentlich  -  ('beschaedigt', 24)  /  10922.6666667
# eigentlich  -  ('shooting', 23)  /  2849.39130435
# eigentlich  -  ('connection', 22)  /  2978.90909091
# eigentlich  -  ('schlacht', 22)  /  2978.90909091
# eigentlich  -  ('lackierung', 22)  /  47662.5454545
# eigentlich  -  ('nachlass', 22)  /  11915.6363636
# eigentlich  -  ('blackwhite', 22)  /  11915.6363636
# eigentlich  -  ('trendlinie', 21)  /  780.19047619
# eigentlich  -  ('leichtem', 21)  /  3120.76190476
# eigentlich  -  ('geeignet', 21)  /  780.19047619
# eigentlich  -  ('schickes', 21)  /  49932.1904762
# eigentlich  -  ('gebrauchten', 21)  /  12483.047619
# eigentlich  -  ('auschlachten', 21)  /  49932.1904762
# eigentlich  -  ('aktivlenkung', 20)  /  52428.8
# eigentlich  -  ('mittellang', 20)  /  3276.8
# eigentlich  -  ('ehrlicher', 20)  /  819.2
# eigentlich  -  ('elektrisch', 20)  /  51.2
# eigentlich  -  ('chiptuning', 20)  /  13107.2
# eigentlich  -  ('geflegter', 19)  /  3449.26315789
# eigentlich  -  ('elektrischem', 19)  /  862.315789474
# eigentlich  -  ('spacelight', 19)  /  3449.26315789
# eigentlich  -  ('bilstein', 19)  /  862.315789474
# eigentlich  -  ('aehnlich', 19)  /  53.8947368421
# eigentlich  -  ('ehrliches', 18)  /  910.222222222
# eigentlich  -  ('independence', 18)  /  14563.5555556
# eigentlich  -  ('eleganze', 18)  /  3640.88888889
# eigentlich  -  ('highlight', 18)  /  227.555555556
# eigentlich  -  ('rechnungen', 18)  /  14563.5555556
# eigentlich  -  ('hightline', 18)  /  56.8888888889
# eigentlich  -  ('seltenes', 18)  /  3640.88888889
# eigentlich  -  ('challenger', 17)  /  61680.9411765
# eigentlich  -  ('anhaengelast', 17)  /  15420.2352941
# eigentlich  -  ('infiniti', 17)  /  3855.05882353
# eigentlich  -  ('frontscheibe', 17)  /  61680.9411765
# eigentlich  -  ('nagelneu', 17)  /  963.764705882
# eigentlich  -  ('erhaltene', 17)  /  3855.05882353
# eigentlich  -  ('sportliches', 17)  /  963.764705882
# eigentlich  -  ('econoline', 17)  /  240.941176471
# eigentlich  -  ('dachreling', 16)  /  4096.0
# eigentlich  -  ('rechnung', 16)  /  16384.0
# eigentlich  -  ('naechste', 16)  /  16384.0
# eigentlich  -  ('wildschaden', 16)  /  65536.0
# eigentlich  -  ('geliebter', 16)  /  4096.0
# eigentlich  -  ('einmalig', 16)  /  256.0
# eigentlich  -  ('climatic', 16)  /  1024.0
# eigentlich  -  ('matching', 16)  /  16384.0
# eigentlich  -  ('begleiter', 16)  /  4096.0
# eigentlich  -  ('einzelteile', 15)  /  273.066666667
# eigentlich  -  ('seltenheit', 14)  /  1170.28571429
# eigentlich  -  ('challenge', 14)  /  74898.2857143
# eigentlich  -  ('teiletrger', 13)  /  1260.30769231
# eigentlich  -  ('lichtsensor', 12)  /  87381.3333333
# eigentlich  -  ('technischen', 12)  /  21845.3333333
# ('highline', 4221, 0.97038616441601522)

# %%
# %%time
#should approximately take 10x44 secs = 7.5minutes
src_count_s = sorted([x for x in src_count if x[1] >= 10], key=lambda x:x[1], reverse=True)
src_best_subs = []
ts = []
ns = []
for (i,x) in enumerate(src_count):
    src_best_subs.append(word_subs(x, src_count_s))
    if i % 100 == 0:
        ts.append(time.perf_counter())
        ns.append(i)
        time_left = 0
        if i > 0:
            time_left = forecast_timeleft(ns, ts, len(src_count), alpha=0.01)
        print("Processed {0} items, run-time is {1:.3f}, {2:.3f} left".format(i, (ts[-1] - ts[0]), time_left),end='\r')
# Out:
# Processed 24900 items, run-time is 478.618, 697.381 leftt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-326-e8ade9a2991c> in <module>()
# ----> 1 get_ipython().run_cell_magic('time', '', '#should approximately take 10x44 secs = 7.5minutes\nsrc_count_s = sorted([x for x in src_count if x[1] >= 10], key=lambda x:x[1], reverse=True)\nsrc_best_subs = []\nts = []\nns = []\nfor (i,x) in enumerate(src_count):\n    src_best_subs.append(word_subs(x, src_count_s))\n    if i % 100 == 0:\n        ts.append(time.perf_counter())\n        ns.append(i)\n        time_left = 0\n        if i > 0:\n            time_left = forecast_timeleft(ns, ts, len(src_count), alpha=0.01)\n        print("Processed {0} items, run-time is {1:.3f}, {2:.3f} left".format(i, (ts[-1] - ts[0]), time_left),end=\'\\r\')')
#
# C:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2113             magic_arg_s = self.var_expand(line, stack_depth)
#    2114             with self.builtin_trap:
# -> 2115                 result = fn(magic_arg_s, cell)
#    2116             return result
#    2117
#
# <decorator-gen-60> in time(self, line, cell, local_ns)
#
# C:\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# C:\Anaconda3\lib\site-packages\IPython\core\magics\execution.py in time(self, line, cell, local_ns)
#    1183         else:
#    1184             st = clock2()
# -> 1185             exec(code, glob, local_ns)
#    1186             end = clock2()
#    1187             out = None
#
# <timed exec> in <module>()
#
# <ipython-input-245-ee22007e8d91> in word_subs(p, plist)
#      24         if p[0] == p2[0]:
#      25             continue
# ---> 26         prob = word_prob(p, p2, pow_base)
#      27         if bestp is None or bestp[2] > prob:
#      28             bestp = (p2[0], p2[1], prob)
#
# <ipython-input-245-ee22007e8d91> in word_prob(p1, p2, pow_base)
#       6     s2 = set(p2[0])
#       7     low_err = min(len(s1.difference(s2)), len(s2.difference(s1)))
# ----> 8     if np.power(pow_base, low_err) * float(p1[1] / p2[1]) > 1.0:
#       9         return 1.0
#      10
#
# KeyboardInterrupt:

# %%
t = np.array(ts)
n = np.array(ns)
s = (t[1:]-t[:-1]) / (n[1:]-n[:-1])
xn = (np.max(n) - n) / (n[-1] - n[-2])
w = np.exp(-xn[1:] * 0.5)
avg_s = np.sum(s * w) / np.sum(w)
avg_s *

# %%
forecast_time(ns, ts, 42000)
# Out:
# 76.390739773632959
